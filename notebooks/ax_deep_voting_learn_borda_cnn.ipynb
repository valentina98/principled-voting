# %% [markdown]
# # Supervised learning of a classical voting rule

# %%
# %cd ..

import exp_learn_borda

architecture = 'CNN'  # MLP, CNN, WEC, SetTransformer
election_sampling = {'probmodel': 'IC'}
random_seed = 42  # seed for reproducibility
batch_size = 32
learning_rate = 1e-4
# Out:
# /proj/uni/thesis/ax_deep_voting

# %% [markdown]
# ### 100% Borda learned for 3 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=3,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # size of each training batch
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Borda',  # target voting rule for training labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-03-34_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 275.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 275 samples | 275 labels | 3 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 275 profiles
# [ExpBorda] Now initializing the model
# ...

# %% [markdown]
# ### 100% Plurality learned for 3 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=3,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # size of each training batch
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Plurality',  # target voting rule for training labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-03-56_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 275.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 275 samples | 275 labels | 3 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 275 profiles
# ...

# %% [markdown]
# ### 100% Copeland learned for 3 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=3,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # size of each training batch
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Copeland',  # target voting rule for training labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-04-17_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 275.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 275 samples | 275 labels | 3 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 275 profiles
# ...

# %% [markdown]
# ### 100% learned Borda for 3 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=5,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # increased number of gradient steps for longer training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # training batch size
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Borda',  # voting rule used to generate labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-04-37_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | 9397 labels | 5 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 9397 profiles
# ...

# %% [markdown]
# ### 100% learned Plurality for 3 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=5,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # training batch size
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Plurality',  # voting rule used to generate labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-04-57_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | 9397 labels | 5 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 9397 profiles
# ...

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=5,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # training batch size
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Plurality',  # voting rule used to generate labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-29_14-46-10_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | 9397 labels | 5 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 9397 profiles
# ...

# %% [markdown]
# ### 100% learned Copeland for 3 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,  # model architecture: word embedding classifier
    max_num_voters=5,  # maximum number of voters in a profile
    max_num_alternatives=3,  # maximum number of alternatives (candidates)
    election_sampling=election_sampling,  # uniform distribution over rankings
    num_gradient_steps=1000,  # number of gradient steps during training
    report_intervals=100,  # frequency of evaluation logging
    dev_dataset_size=100,  # size of the evaluation (dev) dataset
    random_seed=random_seed,  # seed for reproducibility
    batch_size=batch_size,  # training batch size
    learning_rate=learning_rate,  # learning rate for optimizer
    save_model=True,  # whether to save the trained model
    voting_rule='Copeland',  # voting rule used to generate labels
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-07-15_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_3a_32032_train.pt
# [PrefVotingDataset] The dataset contains: 32032 samples | 32032 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_3a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | 9397 labels | 5 voters | 3 alternatives
# [ExpBorda] Partition sizes | Train: 32032 profiles | Dev: 100 | Test: 9397 profiles
# ...

# %% [markdown]
# ### Learning of Borda for 5 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=3,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,  
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Borda',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-07-30_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 1757219.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_3v_5a_eval.pt
# [PrefVotingDataset] The dataset contains: 300000 samples | 300000 labels | 3 voters | 5 alternatives
# ...

# %% [markdown]
# ### Learning Plurality for 5 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=3,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Plurality',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-11-29_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 1757219.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_3v_5a_eval.pt
# ...

# %% [markdown]
# ### Learning Copeland for 5 alternatives and 3 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=3,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Copeland',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_16-14-18_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 3 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 1757219.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_3v_5a_eval.pt
# ...

# %% [markdown]
# ### Learning of Borda for 5 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=5,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,  
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Borda',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_22-17-43_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 25100620741.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/borda_5v_5a_eval.pt
# [PrefVotingDataset] The dataset contains: 300000 samples | 300000 labels | 5 voters | 5 alternatives
# ...

# %% [markdown]
# ### Learning of Plurality for 5 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=5,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,  
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Plurality',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_22-22-11_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 25100620741.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/plurality_5v_5a_eval.pt
# ...

# %% [markdown]
# ### Learning of Copeland for 5 alternatives and 5 voters

# %%
exp_learn_borda.experimentBorda(
    architecture=architecture,
    max_num_voters=5,
    max_num_alternatives=5,
    election_sampling=election_sampling,
    num_gradient_steps=10000,  
    report_intervals=100,
    dev_dataset_size=100,
    random_seed=random_seed,
    batch_size=batch_size,
    learning_rate=learning_rate,
    save_model=True,
    voting_rule='Copeland',
)
# Out:
# [ExpBorda] Saving location: ./results/exp_borda/CNN/exp_2025-09-13_22-52-48_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_5a_320032_train.pt
# [PrefVotingDataset] The dataset contains: 320032 samples | 320032 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_5a_100_dev.pt
# [PrefVotingDataset] The dataset contains: 100 samples | 100 labels | 5 voters | 5 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 25100620741.
# [PrefVotingDataset] The number of samples to evaluate is too big, so 300,000 random samples will be used.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/copeland_5v_5a_eval.pt
# ...
