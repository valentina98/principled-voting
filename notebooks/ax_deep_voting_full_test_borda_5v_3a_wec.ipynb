# %% [markdown]
# # Learning axioms

# %%
# %cd ..

import exp_learn_axioms
import utils_dicts

max_num_voters = 5
max_num_alternatives = 3
random_seed = 42
learning_rate = 1e-4
batch_size = 32
election_sampling=  {'probmodel': 'IC'}
num_gradient_steps = 1000
report_intervals = 100
dev_dataset_size = 100
architecture = 'WEC'  # MLP, CNN, WEC, SetTransformer

model_path_borda_3v_3a = './results/exp_borda/WEC/exp_2025-08-27_20-21-58_IC'
model_path_borda_5v_3a = './results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC'
model_path_borda_3v_5a = './results/exp_borda/WEC/exp_2025-08-27_20-56-57_IC'
model_path_borda_5v_5a = './results/exp_borda/WEC/exp_2025-08-27_19-46-32_IC'
model_path = model_path_borda_5v_3a

# %% [markdown]
# ## Unupervised training from scratch

# %% [markdown]
# ### Condorcet from scratch

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model=[
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler = None,
    weight_decay = 0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-28_07-01-45_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Active axioms for optimization: Condorcet1 (weight: 1)
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model=[
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=5000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler = None,
    weight_decay = 0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_12-54-21_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_160132.pt
# [PrefVotingDataset] The dataset contains: 160132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model=[
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=10000,  # extended training
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler = None,
    weight_decay = 0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_20-06-18_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_320132.pt
# [PrefVotingDataset] The dataset contains: 320132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %% [markdown]
# ### Independence from scratch

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model=[
        'Independence',
    ],
    axiom_opt={
        'Independence':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-28_07-04-39_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Active axioms for optimization: Independence (weight: 1)
# ...

# %% [markdown]
# ### Multiple axioms from scratch

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_23-23-12_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_11-42-25_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-28_07-13-03_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=10000,  # extended training
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_12-25-00_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_320132.pt
# [PrefVotingDataset] The dataset contains: 320132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_23-24-51_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'No_winner':{'weight':1},
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_23-32-10_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Pretraining word embeddings
# [WEC] Done pretraining word embeddings
# [WEC] Number of word embedding tokens:  11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# [Exp3] Saving the word embeddings
# ...

# %% [markdown]
# ## Unsupervised training from a checkpoint

# %% [markdown]
# ### Condorcet from Borda

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
    axioms_check_model= [
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_19-13-06_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
    axioms_check_model= [
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=5000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_12-49-55_IC
# [PrefVotingDataset] No dataset file found. Generating dataset from scratch...
# [PrefVotingDataset] Generating 160132 random sample profiles...
# [PrefVotingDataset] Profiles with up to 5 voters and 3 alternatives will be generated...
# [PrefVotingDataset] Dataset generated and saved to results/unsupervised_5v_3a_160132.pt
# [PrefVotingDataset] The dataset contains: 160132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
    axioms_check_model= [
        'Condorcet',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=10000,  # more steps
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-28_07-57-46_IC
# [PrefVotingDataset] No dataset file found. Generating dataset from scratch...
# [PrefVotingDataset] Generating 320132 random sample profiles...
# [PrefVotingDataset] Profiles with up to 5 voters and 3 alternatives will be generated...
# [PrefVotingDataset] Dataset generated and saved to results/unsupervised_5v_3a_320132.pt
# [PrefVotingDataset] The dataset contains: 320132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# ...

# %% [markdown]
# ### Independence from Borda

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
    axioms_check_model= [
        'Independence',
    ],
    axiom_opt={
        'Independence':{'weight':1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-28_06-27-37_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %% [markdown]
# ### Multiple axioms from Borda

# %%
# not needed because it is already admissible
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
        axioms_check_model= [
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-05_23-40-49_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
        axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-08-29_15-42-08_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
        axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_12-10-01_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...

# %%
exp_learn_axioms.experimentAxioms(
    architecture=architecture,
    max_num_voters=max_num_voters,
    max_num_alternatives=max_num_alternatives,
    election_sampling=election_sampling,
    architecture_parameters = {
        'load_embeddings_from': model_path
    },
        axioms_check_model= [
        'Condorcet',
        'Independence',
    ],
    axiom_opt={
        'No_winner':{'weight':1},
        'Inadmissible':{'weight':1},
        'Condorcet1':{'weight':1},
        'Independence':{'weight':0.1},
    }, 
    comp_rules_axioms=[],
    comp_rules_similarity=list(utils_dicts.dict_rules_all_fast.keys()),
    num_gradient_steps=1000,
    report_intervals=100,
    dev_dataset_size=100,
    batch_size=batch_size,
    random_seed=random_seed,
    learning_rate=learning_rate,
    learning_scheduler=None,
    weight_decay=0,
    load_model_from=model_path,
    save_model=True,
)
# Out:
# [Exp3] Using default distance functions for each axiom
# Saving location: ./results/exp3/WEC/exp3_2025-09-06_12-16-42_IC
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_32132.pt
# [PrefVotingDataset] The dataset contains: 32132 samples | no labels | 5 voters | 3 alternatives
# [PrefVotingDataset] The number of samples for exhaustive enumeration is 9397.
# [PrefVotingDataset] A dataset file is found, loading dataset...
# [PrefVotingDataset] Dataset loaded from results/unsupervised_5v_3a_eval.pt
# [PrefVotingDataset] The dataset contains: 9397 samples | no labels | 5 voters | 3 alternatives
# [Exp3] Now initializing the model
# [WEC] Loading pretrained word embeddings from ./results/exp_borda/WEC/exp_2025-08-27_14-14-34_IC/pre_embeddings.bin
# [WEC] Number of word embedding tokens: 11
# [WEC] Word embedding tokens:  0-1-1, 01-1, 012, 021, 10-1, 102, 120, 201, 210, PAD, UNK
# ...
